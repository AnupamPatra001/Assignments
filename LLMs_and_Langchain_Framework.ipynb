# %% [markdown]
# **Question 1: What are Large Language Models (LLMs) and how do they function?**
#
# Large Language Models (LLMs) are advanced AI systems designed to understand and generate human-like language. Examples include models like ChatGPT and GPT-4. They are called “large” because they are trained on massive amounts of text data—books, articles, websites, and more.
#
# How they function (in simple terms)
#
# Think of an LLM like a highly trained reader that has seen millions of conversations and texts. Instead of memorizing exact answers, it learns patterns in language.
#
# Here's how it works step by step:
#
# Training phase
# The model is trained on huge datasets. During this phase, it learns:
#
# Grammar and sentence structure
# Meaning of words in different contexts
# Relationships between ideas
#
# Technically, it uses a deep learning architecture called a transformer, which helps it understand context better than older models.
#
# Understanding input
# When you type a question, the model:
# Breaks it into smaller units called tokens (words or parts of words)
# Analyzes the context and intent behind your input
#
# Generating output
# The model doesn't “think” like humans. Instead, it:
#
# Predicts the most likely next word based on probabilities
# Repeats this process word by word to form a complete response
#
# For example, if you type "The sky is…", it predicts words like “blue” based on learned patterns.
#
# Context awareness
# Modern LLMs can remember the flow of a conversation (within limits), allowing them to give more relevant and coherent answers.
#
# **Question 2: Discuss the impact of LLMs on traditional software development
# approaches.**
#
# 1. Shift from Manual Coding to AI-Assisted Development
#
# Traditionally, developers wrote most of the code manually. With LLMs:
#
# Developers can generate code snippets, functions, or even entire modules using prompts.
# This reduces development time and effort.
# Focus shifts from writing code to reviewing and refining AI-generated code.
# 2. Faster Development Lifecycle
#
# LLMs accelerate different stages of the Software Development Life Cycle (SDLC):
#
# Requirement analysis: Convert natural language into technical specifications.
# Design & coding: Generate boilerplate and repetitive code.
# Testing: Auto-generate test cases and debugging suggestions.
#
# Result: Faster prototyping and shorter release cycles.
#
# 3. Reduced Entry Barrier
#
# Earlier, strong programming knowledge was mandatory. Now:
#
# Beginners can build applications using natural language prompts.
# Non-developers (citizen developers) can participate in software creation.
#
# This democratizes software development but also raises concerns about code quality.
#
# 4. Change in Developer Role
#
# The role of a developer is evolving:
#
# From coder → problem solver + AI supervisor
# Developers now need skills in:
# Prompt engineering
# Code validation
# System design
# 5. Improved Productivity but Dependency Risk
#
# LLMs increase productivity by:
#
# Reducing repetitive work
# Providing instant solutions
#
# However:
#
# Over-reliance can weaken core programming skills
# Developers may accept incorrect or inefficient code without proper validation
# 6. Impact on Software Quality
#
# Positive:
#
# Faster debugging
# Automated documentation generation
# Consistent coding patterns
#
# Negative:
#
# Risk of insecure or suboptimal code
# Lack of deep understanding of generated logic
# 7. Collaboration and Workflow Changes
# Integration of AI tools into IDEs (e.g., Copilot in VS Code) changes workflows
# Teams may rely more on AI suggestions than peer discussions
# Documentation and communication become more AI-assisted
# 8. Ethical and Security Concerns
# Code may include vulnerabilities
# Licensing and plagiarism issues
# Data privacy risks when using proprietary codebases
#
# **Question 3: What are the key advantages and limitations of using LLMs in real-world applications?**
#
# Advantages of LLMs
# 1. High Efficiency and Productivity
# Automate tasks like content writing, coding, and customer support
# Reduce time required for repetitive work
# Enable faster decision-making and execution
# 2. Natural Language Understanding
# Can understand and generate human-like text
# Useful in chatbots, virtual assistants, and translation systems
# Improves user interaction and experience
# 3. Versatility (Multi-domain Usage)
# Applicable in various fields: healthcare, education, finance, software development
# One model can perform multiple tasks (writing, summarizing, coding, etc.)
# 4. Cost Reduction
# Reduces need for large human workforce for routine tasks
# Automates customer service and documentation
# 5. 24/7 Availability
# Can operate continuously without fatigue
# Ideal for real-time support systems
# 6. Learning and Adaptability
# Can be fine-tuned for specific domains
# Improves performance with better training data
# Limitations of LLMs
# 1. Lack of True Understanding
# LLMs do not “think” or understand like humans
# They generate responses based on patterns, not real comprehension
# 2. Possibility of Incorrect or Misleading Output
# Can produce hallucinations (false or fabricated information)
# May sound confident even when wrong
# 3. Data Dependency and Bias
# Output depends on training data
# Can reflect biases present in the data (social, cultural, etc.)
# 4. Security and Privacy Concerns
# Risk of exposing sensitive data
# Not always safe for confidential or proprietary information
# 5. High Computational Cost
# Training and deploying LLMs require significant computing resources
# Expensive infrastructure (GPUs, cloud services)
# 6. Limited Context and Memory
# Cannot remember long-term interactions reliably
# Context window is limited
# 7. Ethical and Legal Issues
# Plagiarism concerns
# Misuse for generating fake content or misinformation.
#
# **Question 4: Describe how different industries are being transformed by the use of LLMs. Provide examples.**
#
# 1. Healthcare Industry
# Transformation:
# Assists doctors in diagnosis and clinical documentation
# Automates patient interaction through AI chatbots
# Examples:
# Symptom-checking assistants
# Generating medical reports and summaries
# Drug research support using large datasets
#
# Impact: Improves efficiency, reduces workload, and enhances patient care
#
# 2. Education Industry
# Transformation:
# Personalized learning and tutoring systems
# Automated grading and feedback
# Examples:
# AI tutors explaining concepts step-by-step
# Generating study materials, notes, and quizzes
# Language learning assistants
#
# Impact: Makes education more accessible and customized
#
# 3. Software Development Industry
# Transformation:
# AI-assisted coding and debugging
# Automation of documentation and testing
# Examples:
# Tools like GitHub Copilot generating code
# Auto-generating unit tests and fixing bugs
# Converting natural language into code
#
# Impact: Faster development cycles and improved productivity
#
# 4. Customer Service Industry
# Transformation:
# Replacement of traditional call centers with AI chatbots
# Instant and 24/7 customer support
# Examples:
# AI-powered chatbots handling queries
# Automated email responses and complaint resolution
#
# Impact: Reduces operational costs and improves response time
#
# 5. Finance and Banking
# Transformation:
# Automation of financial analysis and reporting
# Fraud detection and risk assessment
# Examples:
# Chatbots for banking assistance
# AI-generated financial summaries and insights
# Detecting unusual transaction patterns
#
# Impact: Better decision-making and enhanced security
#
# 6. Media and Content Creation
# Transformation:
# Automated content generation (articles, blogs, scripts)
# Assistance in creative writing and editing
# Examples:
# Writing news summaries and reports
# Generating social media posts and marketing content
# Scriptwriting for videos
#
# Impact: Speeds up content production and reduces effort
#
# 7. E-commerce and Marketing
# Transformation:
# Personalized recommendations and targeted marketing
# Automated product descriptions and ad content
# Examples:
# Chatbots assisting customers in shopping
# AI-generated product descriptions
# Email marketing automation
#
# Impact: Improves customer engagement and sales
#
# 8. Legal Industry
# Transformation:
# Automating legal research and documentation
# Contract analysis and summarization
# Examples:
# Reviewing contracts for errors
# Generating legal drafts
# Case law research assistance
#
# Impact: Saves time and reduces manual effort
#
# **Question 5: Compare and contrast Langchain and LamaIndex. What unique problems
# does each solve?**
#
# Basic Idea (in simple words)
# LangChain -> Helps you build the logic and workflow of an AI application
# LlamaIndex -> Helps you connect your data to the AI model
#
# Think of it like this:
#
# LangChain = the brain + workflow manager
# LlamaIndex = the data connector + retriever
# Key Differences
# 1. Core Purpose
# LangChain:
# Focuses on building complete applications using LLMs
# (chatbots, agents, pipelines, multi-step reasoning)
# LlamaIndex:
# Focuses on organizing and retrieving data for LLMs
# (documents, PDFs, databases)
# 2. Problem They Solve
# LangChain solves:
# How to chain multiple steps together?
# How to build agents that take decisions?
# How to integrate APIs, tools, memory, and logic?
# LlamaIndex solves:
# How to use your own data with LLMs?
# How to search large document collections efficiently?
# How to give context to the model (RAG - Retrieval Augmented Generation)?
# 3. Working Style
# LangChain:
# Uses chains (step-by-step pipelines)
# Supports agents that can decide actions dynamically
# Integrates tools like APIs, databases, and search
# LlamaIndex:
# Creates indexes from data (like a smart search system)
# Retrieves relevant chunks of data when needed
# Feeds that data to the LLM for better answers
# 4. Use Cases
# LangChain:
# AI chatbots with memory
# Autonomous agents
# Multi-step workflows (e.g., search -> summarize -> respond)
# LlamaIndex:
# Document Q&A systems
# Knowledge base chatbots
# Searching through PDFs, notes, or company data
# 5. Strength
# LangChain: Strong in application logic and orchestration
# LlamaIndex: Strong in data handling and retrieval
# How They Work Together
#
# In real-world systems, they are often combined:
#
# LlamaIndex -> fetches relevant data
# LangChain -> processes it and manages the workflow
# Example:
# A chatbot for your notes
#
# LlamaIndex retrieves the correct notes
# LangChain decides how to answer and interact

# %%
# Question 6: Implement a basic Langchain pipeline using OpenAI’s LLM to answer
# questions based on a user input prompt.
# (Include your Python code and output in the code box below.)
# Install (run once)
# !pip install -U langchain langchain-community transformers sentence-transformers

# Imports
from transformers import pipeline
from langchain_community.llms import HuggingFacePipeline
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# -----------------------------
# Step 1: Initialize Local LLM
# -----------------------------
pipe = pipeline(
    "text-generation",
    model="distilgpt2",
    max_new_tokens=80
)

llm = HuggingFacePipeline(pipeline=pipe)

# -----------------------------
# Step 2: Create Prompt Template
# -----------------------------
prompt = PromptTemplate.from_template(
    "Answer the following question clearly:\n\nQuestion: {question}\nAnswer:"
)

# -----------------------------
# Step 3: Create LangChain Pipeline
# -----------------------------
chain = prompt | llm | StrOutputParser()

# -----------------------------
# Step 4: Run Example
# -----------------------------
question = "What is Artificial Intelligence?"
response = chain.invoke({"question": question})

print("Q:", question)
print("A:", response)
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# ...

# %%
# Install required libraries
# !pip install requests langchain langchain-community transformers torch

# Imports
import requests
from transformers import pipeline
from langchain_community.llms import HuggingFacePipeline
from langchain_core.prompts import PromptTemplate

# Step 1: Create a function to call Weather API
def get_weather(city):
    url = f"https://wttr.in/{city}?format=3"   # Free weather API (no key needed)
    response = requests.get(url)
    return response.text

# Step 2: Load free LLM (no API key)
pipe = pipeline("text-generation", model="gpt2")
llm = HuggingFacePipeline(pipeline=pipe)

# Step 3: Prompt template
prompt = PromptTemplate.from_template(
    "Given the weather information: {weather}\n"
    "Answer the user question: {question}\n"
    "Provide a clear and helpful response."
)

# Step 4: Create chain
chain = prompt | llm

# Step 5: User input
city = "Bhubaneswar"
question = "Should I carry an umbrella today?"

# Step 6: Fetch weather data
weather_data = get_weather(city)

# Step 7: Run LLM
response = chain.invoke({
    "weather": weather_data,
    "question": question
})

# Step 8: Output
print("Weather Data:", weather_data)
print("\nLLM Response:\n", response)
# Out:
# ...
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Weather Data: bhubaneswar: ð«  +31Â°C
#
#
# LLM Response:
#  Given the weather information: bhubaneswar: ð«  +31Â°C
#
# Answer the user question: Should I carry an umbrella today?
# Provide a clear and helpful response.
#
# Question: ð«  +31Â°C
#
# Answer the user question: Should you carry an umbrella today?
#
# Provide a clear and helpful response.
#
# Question: ð«  +31Â°C
#
# Answer the user question: Should you carry an umbrella today?
#
# Provide a clear and helpful response.
#
# Question: ð«  +31Â°C
#
# Answer the user question: Should you carry an umbrella today?
#
# ...

# %%
# Question 8: Create a LamaIndex implementation that indexes a local text file and
# retrieves answers from it.
# (Include your Python code and output in the code box below.)
# Install (run once)
# !pip install -U llama-index llama-index-embeddings-huggingface \
               transformers sentence-transformers

# Imports
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from transformers import pipeline

# -----------------------------
# Step 1: Setup embedding (NO OpenAI)
# -----------------------------
Settings.embed_model = HuggingFaceEmbedding(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# -----------------------------
# Step 2: Create local text file
# -----------------------------
with open("info.txt", "w") as f:
    f.write("""
    Data Science involves collecting, analyzing, and interpreting data.
    It uses techniques from statistics, machine learning, and data analysis.
    Python is widely used in Data Science due to its simplicity and libraries.
    """)

# -----------------------------
# Step 3: Load and index file
# -----------------------------
documents = SimpleDirectoryReader(input_files=["info.txt"]).load_data()
index = VectorStoreIndex.from_documents(documents)

# -----------------------------
# Step 4: Retrieval (NO LLM inside)
# -----------------------------
retriever = index.as_retriever(similarity_top_k=1)

# -----------------------------
# Step 5: Simple answer generation
# -----------------------------
generator = pipeline(
    "text-generation",
    model="distilgpt2",
    max_new_tokens=80
)

def ask_question(question):
    # Retrieve relevant text
    nodes = retriever.retrieve(question)
    context = nodes[0].text[:300]

    # Create prompt
    prompt = f"""
    Answer based on the context.

    Context: {context}
    Question: {question}
    Answer:
    """

    result = generator(prompt)[0]["generated_text"]
    return result.split("Answer:")[-1].strip()

# -----------------------------
# Run Example
# -----------------------------
q = "Why is Python used in Data Science?"
print("Q:", q)
print("A:", ask_question(q))
# Out:
# ...
# WARNING: huggingface-hub 1.7.2 does not provide the extra 'inference'
# ...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
# Question 9: Demonstrate combining Langchain with LamaIndex to create a simple
# document-based Q&A chatbot.
# (Include your Python code and output in the code box below.)
# Install required libraries
# Install (run once)
# !pip install -U llama-index llama-index-embeddings-huggingface \
               langchain transformers sentence-transformers

# Imports
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from transformers import pipeline
from langchain_core.prompts import PromptTemplate

# -----------------------------
# Step 1: LlamaIndex (Retrieval)
# -----------------------------

# Local embedding (no OpenAI)
Settings.embed_model = HuggingFaceEmbedding(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# Create sample document
with open("data.txt", "w") as f:
    f.write("""
    Artificial Intelligence (AI) is transforming industries by automating tasks.
    Machine Learning is a subset of AI that enables systems to learn from data.
    Deep Learning uses neural networks for complex problem solving.
    """)

# Load and index document
documents = SimpleDirectoryReader(input_files=["data.txt"]).load_data()
index = VectorStoreIndex.from_documents(documents)

# Retriever (safe, no LLM here)
retriever = index.as_retriever(similarity_top_k=1)

# -----------------------------
# Step 2: LangChain (Generation)
# -----------------------------

# Local LLM
generator = pipeline(
    "text-generation",
    model="distilgpt2",
    max_new_tokens=80
)

# Prompt template (LangChain)
prompt = PromptTemplate.from_template(
    "Answer based on the context.\n\nContext: {context}\nQuestion: {question}\nAnswer:"
)

# -----------------------------
# Step 3: Combine both
# -----------------------------

def chatbot(question):
    # Get relevant context from LlamaIndex
    nodes = retriever.retrieve(question)
    context = nodes[0].text[:300]

    # Create prompt
    final_prompt = prompt.format(context=context, question=question)

    # Generate answer using LLM
    output = generator(final_prompt)[0]["generated_text"]

    return output.split("Answer:")[-1].strip()

# -----------------------------
# Run Example
# -----------------------------
q = "What is Machine Learning?"
print("Q:", q)
print("A:", chatbot(q))
# Out:
# ...
# WARNING: huggingface-hub 1.7.2 does not provide the extra 'inference'
# ...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
# Install
# !pip install -U llama-index llama-index-embeddings-huggingface \
               transformers sentence-transformers

# Imports
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from transformers import pipeline

# ✅ Only embeddings (NO LLM inside LlamaIndex)
Settings.embed_model = HuggingFaceEmbedding(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# Create document
with open("legal.txt", "w") as f:
    f.write("""
    This contract establishes that the supplier is responsible for delivery delays.
    The liability clause states that damages will be compensated under certain conditions.
    Both parties must adhere to the terms stated above.
    """)

# Index
documents = SimpleDirectoryReader(input_files=["legal.txt"]).load_data()
index = VectorStoreIndex.from_documents(documents)

# 🔥 PURE retrieval (no LLM → no crash)
retriever = index.as_retriever(similarity_top_k=1)

# ✅ Separate LLM (safe)
generator = pipeline(
    "text-generation",
    model="distilgpt2",
    max_new_tokens=80
)

# Chat function
def chatbot(question):
    nodes = retriever.retrieve(question)
    context = nodes[0].text[:300]   # limit context

    prompt = f"""
    Answer the question based only on the context.

    Context: {context}
    Question: {question}
    Answer:
    """

    result = generator(prompt)[0]["generated_text"]
    return result.split("Answer:")[-1].strip()

# Run
q = "What does the liability clause state?"
print("Q:", q)
print("A:", chatbot(q))
# Out:
# ...
# WARNING: huggingface-hub 1.7.2 does not provide the extra 'inference'
# ...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...
